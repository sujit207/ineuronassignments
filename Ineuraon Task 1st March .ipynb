# %%
import pandas as pd 
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
data=requests.get(url)

# %%
d1=data.json()

# %%
len(d1)
# Out:
# 30

# %%
for i in range(len(d1[0])):
    print(d1[i]['user']['id'])
# Out:
# 10647082
# 96553566
# 12093095
# 8078968
# 51996504
# 24256554
# 25440862
# 8078968
# 8078968
# 24256554
# 5902745
# 4156237
# 10647082
# 100502242
# 10540830
# 10297014
# 15113894
# 36619387
# 8011761
# 8519523
# 36619387
# 8519523
# 4667801
# 7980666
# 8179126
# 6145801
# 10647082
# 45396231
# 36619387

# %%
df2=pd.DataFrame(d1)

# %%
d2=pd.DataFrame(d1,columns=['id','user'])

# %%
d3=d2['user']

# %%
type(d3)
# Out:
# pandas.core.series.Series

# %%
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
l6=[]
l7=[]
l8=[]
l9=[]
l10=[]
l11=[]
l12=[]
l13=[]
l14=[]
l15=[]
l16=[]
l17=[]
l18=[]
l19=[]

for i in range(len(d3)):
    l1.append(d3[i]['login'])
    l2.append(d3[i]['id'])
    l3.append(d3[i]['node_id'])
    l4.append(d3[i]['avatar_url'])
    l5.append(d3[i]['gravatar_id'])
    l6.append(d3[i]['url'])
    l7.append(d3[i]['html_url'])
    l8.append(d3[i]['followers_url'])
    l9.append(d3[i]['following_url'])
    l10.append(d3[i]['gists_url'])
    l11.append(d3[i]['starred_url'])
    l12.append(d3[i]['subscriptions_url'])
    l13.append(d3[i]['organizations_url'])
    l14.append(d3[i]['repos_url'])
    l15.append(d3[i]['events_url'])
    l16.append(d3[i]['received_events_url'])
    l18.append(d3[i]['type'])
    l19.append(d3[i]['site_admin'])
s1=pd.DataFrame(l1)
s2=pd.DataFrame(l2)
s3=pd.DataFrame(l3)
s4=pd.DataFrame(l4)
s5=pd.DataFrame(l5)
s6=pd.DataFrame(l6)
s7=pd.DataFrame(l7)
s8=pd.DataFrame(l8)
s9=pd.DataFrame(l9)
s10=pd.DataFrame(l10)
s11=pd.DataFrame(l11)
s12=pd.DataFrame(l12)
s13=pd.DataFrame(l13)
s14=pd.DataFrame(l14)
s15=pd.DataFrame(l15)
s16=pd.DataFrame(l16)
s17=pd.DataFrame(l17)
s18=pd.DataFrame(l18)
s19=pd.DataFrame(l19)

# %%
df=pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,s19],axis=1)

# %%
df1=df.copy()

# %%
dfnew=pd.concat([df2,df1],axis=1)

# %%
dfnew.head(2)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           html_url          id  \
# 0  https://github.com/pandas-dev/pandas/pull/46191  1154944516
# ...

# %%
writer=pd.ExcelWriter('task1.xlsx')

# %%
dfnew.to_excel(writer)

# %%
writer.save()
